# %%
import numpy as np
import pandas as pd

# %%
#%cd('d:/Work/Python/MyCode/Stock')
day = pd.read_hdf("d:\Work\Python\MyCode\Stock\data\k_day_2018-03-31.hd5", 'day')
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7640086 entries, 0 to 7640085
# Data columns (total 10 columns):
# datetime    datetime64[ns]
# code        object
# open        float64
# close       float64
# high        float64
# low         float64
# vol         float64
# amount      float64
# tor         float64
# vr          float64
# dtypes: datetime64[ns](1), float64(8), object(1)
# memory usage: 641.2+ MB

# %%
day.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>code</th>
#       <th>open</th>
#       <th>close</th>
#       <th>high</th>
#       <th>low</th>
#       <th>vol</th>
#       <th>amount</th>
#       <th>tor</th>
#       <th>vr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2018-03-30</td>
#       <td>300504</td>
#       <td>15.67</td>
#       <td>18.81</td>
#       <td>18.81</td>
#       <td>15.67</td>
#       <td>353.0</td>
#       <td>6.566043e+05</td>
#       <td>0.05</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018-03-30</td>
#       <td>603214</td>
# ...

# %%
day.set_index(['datetime', 'code']).head(50)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>open</th>
#       <th>close</th>
#       <th>high</th>
#       <th>low</th>
#       <th>vol</th>
#       <th>amount</th>
#       <th>tor</th>
#       <th>vr</th>
#     </tr>
#     <tr>
#       <th>datetime</th>
#       <th>code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">2018-03-30</th>
#       <th>300504</th>
#       <td>15.67</td>
#       <td>18.81</td>
#       <td>18.81</td>
#       <td>15.67</td>
# ...

# %%
day.sort_values(by=['code', 'datetime'], inplace=True)

# %%
day.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>code</th>
#       <th>open</th>
#       <th>close</th>
#       <th>high</th>
#       <th>low</th>
#       <th>vol</th>
#       <th>amount</th>
#       <th>tor</th>
#       <th>vr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7269045</th>
#       <td>2000-01-04</td>
#       <td>000001</td>
#       <td>3.57</td>
#       <td>3.73</td>
#       <td>3.78</td>
#       <td>3.50</td>
#       <td>82160.0</td>
#       <td>147325360.0</td>
#       <td>0.77</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7269044</th>
#       <td>2000-01-05</td>
#       <td>000001</td>
# ...
